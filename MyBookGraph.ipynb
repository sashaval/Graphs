# %% [markdown]
# # Load Packages

# %%
library(tidyverse)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.6
# ✔ forcats   1.0.1     ✔ stringr   1.6.0
# ✔ ggplot2   4.0.1     ✔ tibble    3.3.0
# ✔ lubridate 1.9.4     ✔ tidyr     1.3.1
# ✔ purrr     1.2.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %%
install.packages("svglite")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %% [markdown]
# # Load Data

# %%
my_data <- read.csv("mybookdata.csv")

# %%
my_data
# Out:
#    Month MahBook DeletedScenes Count
# 1  Jan    80334   6413            NA
# 2  Feb    90129   7379          9795
# 3  March  92259  15327         10078
# 4  April 103057  15631         11102
# 5  May   113620  15850         10782
# 6  June  124090  15854         10470
# 7  July  141566  15854         17476
# 8  Aug   152712  15854         11146
# 9  Sept  164648  15854         11936
# 10 Oct   178781  15854         14133
# 11 Nov   195162  17813         18340
# 12 Dec   203853  22193         13071

# %% [markdown]
# ## Creating a New Column

# %%
my_data$mon <- c(1:12)
my_data
# Out:
#    Month MahBook DeletedScenes Count mon
# 1  Jan    80334   6413            NA  1
# 2  Feb    90129   7379          9795  2
# 3  March  92259  15327         10078  3
# 4  April 103057  15631         11102  4
# 5  May   113620  15850         10782  5
# 6  June  124090  15854         10470  6
# 7  July  141566  15854         17476  7
# 8  Aug   152712  15854         11146  8
# 9  Sept  164648  15854         11936  9
# 10 Oct   178781  15854         14133 10
# 11 Nov   195162  17813         18340 11
# 12 Dec   203853  22193         13071 12

# %% [markdown]
# # Calculate the Mean and Standard Deviation of the Months
#
# (excluding January and February)

# %%
mean(my_data$Count[2:12])
# Out:
# [1] 12575.36

# %%
sd(my_data$Count[2:12])
# Out:
# [1] 2935.265

# %% [markdown]
# # Create the Plot

# %% [markdown]
# ## Non-cumulative Plot

# %%
options(repr.plot.width = 10, repr.plot.height = 5)

ggplot(my_data, aes(x = mon, y = MahBook)) +
  geom_line(colour = "black", alpha = 1) + geom_point(size = 2) +
  facet_grid(scales = "free_x", space = "free_x") +
  geom_smooth(
    method = "lm",
    se = FALSE,
    colour = "forest green"
    ) +
  scale_y_continuous(breaks = seq(0, 205000, by = 25000)) +
  scale_x_continuous(breaks = seq(2, 12, by = 2)) +
  labs(
    x = "Month",
    y = "Word Count",
    title = "Manuscript Word Count"
    ) +
  theme(
    axis.title = element_text(size = 13),
    plot.title = element_text(size = 15),
    axis.text = element_text(size = 11),
   )
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# plot without title
